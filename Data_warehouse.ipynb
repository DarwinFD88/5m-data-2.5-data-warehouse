# %% [markdown]
# To authenticate your computer to your GCP account, run:
# – WSL users: gcloud auth application-default login

# %%
from google.cloud import storage

# %%
client = storage.Client(project='My Project DSAI-3')
